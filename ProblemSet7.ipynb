# %%
import yfinance as yf
import pandas as pd
import datetime as dt
import os
import numpy as np
import math

# %% [markdown]
# * Q1 - rebalance portfolio
# * Q2 - define period for which we take into account the size (Market Cap) - moving average of the size over the period Rebalancing every month
# * Q3 - Add rebalancing every REB months e.g. every 12 months, so you keep the same portfolio composition for 12 months each time.
# * Q4 - change percentage of companies taken to each of 2 portfolios

# %%
def pull_stock_data(tickers:str, start:str, end:str, interval:str, stripdateindex:str, column:str) -> pd.DataFrame:
    """
    Returns a dataframe with chosen stock information for last day of the month.

    Parameters:
    -------------
    tickers (str): Yahoo finance tickers for companies divided ONLY by single space
    start (str): start date of the period (format yyyy-mm-dd)
    end (str): end date of the period (format yyyy-mm-dd)
    interval (str): wanted interval (1d, 1m, 1y)
    stripdateindex (str): argument for stripping datetime index down (d - day, m - month, y- year)
    columns (list): list of wanted values, args same as in yahoo finance
    """
    # data download
    df = yf.download(tickers = tickers, start = start, end = end, interval = interval, groupby = 'ticker')
    # changing index from datetime to just year and month
    df['Date'] = df.index
    dfg = df.groupby([df.index.year, df.index.month], as_index=False).last()
    dfg.reset_index(inplace=True, drop=True)
    dfg.set_index('Date', inplace=True)
    dfg.index = pd.to_datetime(dfg.index).to_period(stripdateindex)
    # dropping na rows
    dfg.dropna(inplace = True)
    return dfg[column]

    
def save_to_desktop(dataframe:pd.DataFrame, file_name:str):
    """
    Saves dataframe to desktop in csv format under filename provided

    Parameters:
    ------------
    dataframe (pd.DataFrame): dataframe that is to be saved
    file_name (str): name of the file
    """
    # defining path to desktop on running unit
    desktop = os.path.join(os.path.join(os.environ['USERPROFILE']), 'Desktop')
    # saving file under chosen name on desktop
    dataframe.to_csv(desktop+'/'+file_name+'.csv', sep=';')

# %%
tick = "NKE MSFT XOM INTC CAT WMT JPM F UPS MKC" # stocks universe
st = '2000-12-01'
en = '2020-12-31'
intv = '1d'
strpdt = 'm'
col = ['Close', 'Volume']

stocks_data = pull_stock_data(tick, st, en, intv, strpdt, col)
stocks_data.info()
# Out:
# [*********************100%***********************]  10 of 10 completed
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 241 entries, 2000-12 to 2020-12
# Freq: M
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, CAT)    241 non-null    float64
#  1   (Close, F)      241 non-null    float64
#  2   (Close, INTC)   241 non-null    float64
#  3   (Close, JPM)    241 non-null    float64
#  4   (Close, MKC)    241 non-null    float64
#  5   (Close, MSFT)   241 non-null    float64
#  6   (Close, NKE)    241 non-null    float64
#  7   (Close, UPS)    241 non-null    float64
#  8   (Close, WMT)    241 non-null    float64
#  9   (Close, XOM)    241 non-null    float64
#  10  (Volume, CAT)   241 non-null    int64
#  11  (Volume, F)     241 non-null    int64
#  12  (Volume, INTC)  241 non-null    int64
#  13  (Volume, JPM)   241 non-null    int64
#  14  (Volume, MKC)   241 non-null    int64
#  15  (Volume, MSFT)  241 non-null    int64
#  16  (Volume, NKE)   241 non-null    int64
#  17  (Volume, UPS)   241 non-null    int64
#  18  (Volume, WMT)   241 non-null    int64
#  19  (Volume, XOM)   241 non-null    int64
# dtypes: float64(10), int64(10)
# memory usage: 39.5 KB
# /opt/miniconda3/envs/time-series-env/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:1162: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(

# %% [markdown]
# calculating the stock returns

# %%
stocks_data['Close'] = stocks_data['Close'].pct_change()

# %% [markdown]
# calculating stock excess return - *not sure if that's actually needed*

# %%
fama = pd.read_csv(r"F-F_Research_Data_Factors.CSV", sep=';')
fama['Date'] = pd.to_datetime(fama['Date'].astype('string'), format='%Y%m')
fama.set_index('Date', inplace=True)
fama.index = fama.index.to_period('m')
# Values given in CSV are plain percentages - division by 100
fama = fama.divide(100)
fama.head()

# tickers = stock_returns_full.columns.tolist()
# for i in tickers[:10]:
#     stock_returns_full[i + '_excess_return'] = stock_returns_full[i] - stock_returns_full['RF']

# %%
# Join risk free rates to stock returns in periods
dffull = pd.merge(df1,fama, how='left', left_index=True, right_index=True)
# drop first NULL row which is causing regression to fail
dffull = dffull.dropna()

# %%
# Calculate excess stock return for each company
for i in dffull.columns.tolist()[:10]:
    dffull[i+'_re'] = dffull[i]-dffull['RF']
# Calculate excess Market return
dffull['reM'] = dffull['Mkt-RF']-dffull['RF']
dffull.info()

# %% [markdown]
# ### Portfolio building functions

# %%
# reshape DataFrame
c = stocks_data['Close'].melt(ignore_index=False, value_name="return", var_name='company') #.reset_index()
v = stocks_data['Volume'].melt(ignore_index=False, value_name="volume", var_name='company')
df = pd.merge(c, v, on=["Date",'company'])
df

# %%
def rebalance(df_slice, sort_var, p1, p2):
    """
    Rebalancing returns a list of 2 (for now) portfolios based on the value of decision variable in period taken into account. Period is defined by the length of df_slice per each company.
    TODO: Adjust to return "n" portfolios - this would require changing to sth more sophisticated than head/tail and adjusting form in which percentages are given
    """
    # 1st part - decide on size of each portoflio - based on universe size and percentages assigned to each class of stocks (p1, p2)
    universe_size = df_slice['company'].nunique()
    small_cnt = int((universe_size*p1)//1)
    big_cnt = round(universe_size*p2)

    period_avg = df_slice.groupby('company').mean().reset_index()
    temp_sort = period_avg.sort_values(sort_var, ascending = False)
    # probably some loop over every percentage to get proper companies from sorted list
    # we need to return only the names of companies, because the values of returns at this stage are already aggregated for the whole `period`
    small_comp = temp_sort.tail(small_cnt)['company'].values
    big_comp = temp_sort.head(big_cnt)['company'].values

    return [small_comp, big_comp]


def get_portfolio_stats(date, portfolios, df):
    """
    We are interested in average size (mkt_cap), average return and composition of each portfolio
    Function iterates over list of portfolios and calculates metrics for each of them
    Returns dict of statistics with portfolio number which is used later to construct pd.DataFrame
    """
    ptfs = {}
    for idx, p in enumerate(portfolios, 1):
        p_period_df = df.loc[(df.index == date) & (df.company.isin(p))]
        
        p_name = "ptf_" + str(idx)
        ptfs[p_name+"_return"] = p_period_df['return'].mean()
        ptfs[p_name+"_volume"] = p_period_df['volume'].mean()
        ptfs[p_name+"_stocks"] = p

    return ptfs

def constrcut_portfolios(df, decision_var, reb, per, small_p, big_p):
    """

    """
    test_l = []
    for p_idx, d in enumerate(df.index, 0):
        if p_idx%reb == 0:
            # define slice based on periods taken into account for rebalancing decision (rebalancing could be every 12 months, but periods considered could be e.g. 6 months)
            # TODO: NOT SURE IF THE VALUE OF DECISION VARIABLE SHOULD BE IN PERIOD T OR T-1 
            # if so it's matter of adjusting it here should be -> slice = df[(df.index >= d - per) & (df.index < d)]
            slice = df[(df.index >= d - per+1) & (df.index <= d)]
            
            # return portfolios after rebalancing
            portfolios = rebalance(slice, decision_var, small_p, big_p)
            
        # this is done for each period 
        # calculation of metrics
        stats = get_portfolio_stats(d, portfolios, df)
        test_l.append(stats)
    
    return pd.DataFrame(test_l, index=df.index)

# %%
# TESTING PERIODS - t-1
per = 1
d = df.index[1]
slice = df[(df.index >= d - per) & (df.index < d)]
slice
# Out:
#         company  return    volume
# Date
# 2000-12     CAT     NaN   3051800
# 2000-12       F     NaN   4746800
# 2000-12    INTC     NaN  54053600
# 2000-12     JPM     NaN   9657000
# 2000-12     MKC     NaN    998000
# 2000-12    MSFT     NaN  99977600
# 2000-12     NKE     NaN   8772800
# 2000-12     UPS     NaN   1096000
# 2000-12     WMT     NaN   6582300
# 2000-12     XOM     NaN   9564000

# %% [markdown]
# QUESTION 1 - portfolios sorted based on the past size of company.
# p1 - 50% smallest (by volume) stocks in t-1,
# p2 - 50% biggest (by volume) stocks in t-1

# %%
Q1 = constrcut_portfolios(df=df, decision_var="volume", reb=1, per=1, small_p=.5, big_p=.5)
Q1
# Out:
# PeriodIndex(['2000-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2000-12', '2001-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-01', '2001-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-02', '2001-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-03', '2001-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-04', '2001-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-05', '2001-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-06', '2001-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-07', '2001-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-08', '2001-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-09', '2001-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-10', '2001-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-11', '2001-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-12', '2002-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-01', '2002-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-02', '2002-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-03', '2002-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-04', '2002-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-05', '2002-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-06', '2002-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-07', '2002-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-08', '2002-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-09', '2002-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-10', '2002-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-11', '2002-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-12', '2003-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-01', '2003-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-02', '2003-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-03', '2003-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-04', '2003-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-05', '2003-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-06', '2003-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-07', '2003-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-08', '2003-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-09', '2003-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-10', '2003-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-11', '2003-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-12', '2004-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-01', '2004-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-02', '2004-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-03', '2004-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-04', '2004-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-05', '2004-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-06', '2004-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-07', '2004-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-08', '2004-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-09', '2004-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-10', '2004-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-11', '2004-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-12', '2005-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-01', '2005-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-02', '2005-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-03', '2005-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-04', '2005-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-05', '2005-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-06', '2005-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-07', '2005-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-08', '2005-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-09', '2005-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-10', '2005-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-11', '2005-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-12', '2006-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-01', '2006-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-02', '2006-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-03', '2006-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-04', '2006-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-05', '2006-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-06', '2006-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-07', '2006-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-08', '2006-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-09', '2006-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-10', '2006-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-11', '2006-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-12', '2007-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-01', '2007-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-02', '2007-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-03', '2007-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-04', '2007-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-05', '2007-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-06', '2007-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-07', '2007-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-08', '2007-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-09', '2007-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-10', '2007-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-11', '2007-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-12', '2008-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-01', '2008-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-02', '2008-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-03', '2008-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-04', '2008-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-05', '2008-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-06', '2008-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-07', '2008-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-08', '2008-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-09', '2008-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-10', '2008-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-11', '2008-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-12', '2009-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-01', '2009-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-02', '2009-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-03', '2009-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-04', '2009-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-05', '2009-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-06', '2009-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-07', '2009-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-08', '2009-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-09', '2009-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-10', '2009-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-11', '2009-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-12', '2010-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-01', '2010-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-02', '2010-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-03', '2010-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-04', '2010-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-05', '2010-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-06', '2010-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-07', '2010-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-08', '2010-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-09', '2010-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-10', '2010-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-11', '2010-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-12', '2011-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-01', '2011-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-02', '2011-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-03', '2011-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-04', '2011-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-05', '2011-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-06', '2011-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-07', '2011-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-08', '2011-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-09', '2011-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-10', '2011-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-11', '2011-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-12', '2012-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-01', '2012-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-02', '2012-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-03', '2012-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-04', '2012-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-05', '2012-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-06', '2012-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-07', '2012-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-08', '2012-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-09', '2012-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-10', '2012-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-11', '2012-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-12', '2013-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-01', '2013-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-02', '2013-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-03', '2013-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-04', '2013-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-05', '2013-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-06', '2013-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-07', '2013-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-08', '2013-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-09', '2013-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-10', '2013-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-11', '2013-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-12', '2014-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-01', '2014-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-02', '2014-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-03', '2014-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-04', '2014-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-05', '2014-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-06', '2014-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-07', '2014-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-08', '2014-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-09', '2014-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-10', '2014-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-11', '2014-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-12', '2015-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-01', '2015-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-02', '2015-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-03', '2015-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-04', '2015-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-05', '2015-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-06', '2015-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-07', '2015-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-08', '2015-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-09', '2015-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-10', '2015-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-11', '2015-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-12', '2016-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-01', '2016-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-02', '2016-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-03', '2016-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-04', '2016-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-05', '2016-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-06', '2016-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-07', '2016-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-08', '2016-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-09', '2016-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-10', '2016-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-11', '2016-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-12', '2017-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-01', '2017-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-02', '2017-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-03', '2017-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-04', '2017-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-05', '2017-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-06', '2017-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-07', '2017-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-08', '2017-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-09', '2017-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-10', '2017-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-11', '2017-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-12', '2018-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-01', '2018-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-02', '2018-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-03', '2018-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-04', '2018-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-05', '2018-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-06', '2018-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-07', '2018-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-08', '2018-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-09', '2018-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-10', '2018-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-11', '2018-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-12', '2019-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-01', '2019-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-02', '2019-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-03', '2019-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-04', '2019-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-05', '2019-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-06', '2019-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-07', '2019-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-08', '2019-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-09', '2019-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-10', '2019-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-11', '2019-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-12', '2020-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-01', '2020-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-02', '2020-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-03', '2020-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-04', '2020-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-05', '2020-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-06', '2020-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-07', '2020-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-08', '2020-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-09', '2020-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-10', '2020-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-11', '2020-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2000-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2000-12', '2001-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-01', '2001-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-02', '2001-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-03', '2001-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-04', '2001-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-05', '2001-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-06', '2001-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-07', '2001-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-08', '2001-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-09', '2001-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-10', '2001-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-11', '2001-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-12', '2002-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-01', '2002-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-02', '2002-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-03', '2002-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-04', '2002-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-05', '2002-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-06', '2002-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-07', '2002-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-08', '2002-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-09', '2002-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-10', '2002-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-11', '2002-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-12', '2003-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-01', '2003-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-02', '2003-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-03', '2003-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-04', '2003-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-05', '2003-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-06', '2003-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-07', '2003-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-08', '2003-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-09', '2003-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-10', '2003-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-11', '2003-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-12', '2004-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-01', '2004-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-02', '2004-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-03', '2004-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-04', '2004-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-05', '2004-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-06', '2004-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-07', '2004-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-08', '2004-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-09', '2004-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-10', '2004-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-11', '2004-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-12', '2005-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-01', '2005-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-02', '2005-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-03', '2005-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-04', '2005-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-05', '2005-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-06', '2005-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-07', '2005-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-08', '2005-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-09', '2005-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-10', '2005-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-11', '2005-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-12', '2006-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-01', '2006-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-02', '2006-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-03', '2006-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-04', '2006-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-05', '2006-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-06', '2006-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-07', '2006-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-08', '2006-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-09', '2006-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-10', '2006-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-11', '2006-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-12', '2007-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-01', '2007-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-02', '2007-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-03', '2007-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-04', '2007-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-05', '2007-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-06', '2007-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-07', '2007-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-08', '2007-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-09', '2007-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-10', '2007-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-11', '2007-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-12', '2008-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-01', '2008-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-02', '2008-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-03', '2008-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-04', '2008-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-05', '2008-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-06', '2008-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-07', '2008-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-08', '2008-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-09', '2008-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-10', '2008-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-11', '2008-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-12', '2009-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-01', '2009-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-02', '2009-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-03', '2009-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-04', '2009-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-05', '2009-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-06', '2009-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-07', '2009-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-08', '2009-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-09', '2009-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-10', '2009-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-11', '2009-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-12', '2010-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-01', '2010-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-02', '2010-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-03', '2010-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-04', '2010-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-05', '2010-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-06', '2010-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-07', '2010-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-08', '2010-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-09', '2010-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-10', '2010-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-11', '2010-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-12', '2011-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-01', '2011-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-02', '2011-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-03', '2011-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-04', '2011-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-05', '2011-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-06', '2011-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-07', '2011-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-08', '2011-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-09', '2011-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-10', '2011-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-11', '2011-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-12', '2012-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-01', '2012-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-02', '2012-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-03', '2012-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-04', '2012-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-05', '2012-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-06', '2012-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-07', '2012-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-08', '2012-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-09', '2012-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-10', '2012-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-11', '2012-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-12', '2013-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-01', '2013-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-02', '2013-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-03', '2013-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-04', '2013-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-05', '2013-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-06', '2013-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-07', '2013-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-08', '2013-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-09', '2013-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-10', '2013-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-11', '2013-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-12', '2014-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-01', '2014-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-02', '2014-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-03', '2014-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-04', '2014-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-05', '2014-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-06', '2014-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-07', '2014-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-08', '2014-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-09', '2014-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-10', '2014-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-11', '2014-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-12', '2015-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-01', '2015-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-02', '2015-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-03', '2015-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-04', '2015-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-05', '2015-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-06', '2015-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-07', '2015-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-08', '2015-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-09', '2015-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-10', '2015-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-11', '2015-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-12', '2016-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-01', '2016-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-02', '2016-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-03', '2016-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-04', '2016-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-05', '2016-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-06', '2016-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-07', '2016-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-08', '2016-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-09', '2016-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-10', '2016-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-11', '2016-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-12', '2017-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-01', '2017-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-02', '2017-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-03', '2017-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-04', '2017-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-05', '2017-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-06', '2017-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-07', '2017-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-08', '2017-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-09', '2017-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-10', '2017-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-11', '2017-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-12', '2018-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-01', '2018-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-02', '2018-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-03', '2018-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-04', '2018-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-05', '2018-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-06', '2018-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-07', '2018-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-08', '2018-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-09', '2018-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-10', '2018-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-11', '2018-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-12', '2019-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-01', '2019-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-02', '2019-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-03', '2019-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-04', '2019-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-05', '2019-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-06', '2019-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-07', '2019-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-08', '2019-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-09', '2019-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-10', '2019-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-11', '2019-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-12', '2020-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-01', '2020-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-02', '2020-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-03', '2020-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-04', '2020-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-05', '2020-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-06', '2020-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-07', '2020-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-08', '2020-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-09', '2020-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-10', '2020-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-11', '2020-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2000-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2000-12', '2001-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-01', '2001-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-02', '2001-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-03', '2001-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-04', '2001-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-05', '2001-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-06', '2001-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-07', '2001-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-08', '2001-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-09', '2001-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-10', '2001-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-11', '2001-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2001-12', '2002-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-01', '2002-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-02', '2002-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-03', '2002-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-04', '2002-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-05', '2002-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-06', '2002-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-07', '2002-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-08', '2002-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-09', '2002-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-10', '2002-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-11', '2002-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2002-12', '2003-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-01', '2003-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-02', '2003-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-03', '2003-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-04', '2003-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-05', '2003-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-06', '2003-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-07', '2003-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-08', '2003-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-09', '2003-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-10', '2003-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-11', '2003-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-12', '2004-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-01', '2004-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-02', '2004-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-03', '2004-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-04', '2004-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-05', '2004-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-06', '2004-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-07', '2004-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-08', '2004-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-09', '2004-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-10', '2004-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-11', '2004-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-12', '2005-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-01', '2005-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-02', '2005-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-03', '2005-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-04', '2005-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-05', '2005-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-06', '2005-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-07', '2005-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-08', '2005-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-09', '2005-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-10', '2005-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-11', '2005-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-12', '2006-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-01', '2006-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-02', '2006-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-03', '2006-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-04', '2006-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-05', '2006-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-06', '2006-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-07', '2006-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-08', '2006-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-09', '2006-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-10', '2006-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-11', '2006-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-12', '2007-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-01', '2007-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-02', '2007-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-03', '2007-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-04', '2007-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-05', '2007-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-06', '2007-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-07', '2007-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-08', '2007-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-09', '2007-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-10', '2007-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-11', '2007-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-12', '2008-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-01', '2008-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-02', '2008-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-03', '2008-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-04', '2008-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-05', '2008-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-06', '2008-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-07', '2008-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-08', '2008-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-09', '2008-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-10', '2008-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-11', '2008-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-12', '2009-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-01', '2009-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-02', '2009-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-03', '2009-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-04', '2009-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-05', '2009-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-06', '2009-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-07', '2009-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-08', '2009-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-09', '2009-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-10', '2009-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-11', '2009-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-12', '2010-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-01', '2010-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-02', '2010-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-03', '2010-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-04', '2010-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-05', '2010-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-06', '2010-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-07', '2010-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-08', '2010-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-09', '2010-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-10', '2010-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-11', '2010-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-12', '2011-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-01', '2011-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-02', '2011-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-03', '2011-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-04', '2011-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-05', '2011-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-06', '2011-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-07', '2011-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-08', '2011-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-09', '2011-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-10', '2011-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-11', '2011-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-12', '2012-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-01', '2012-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-02', '2012-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-03', '2012-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-04', '2012-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-05', '2012-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-06', '2012-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-07', '2012-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-08', '2012-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-09', '2012-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-10', '2012-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-11', '2012-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-12', '2013-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-01', '2013-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-02', '2013-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-03', '2013-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-04', '2013-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-05', '2013-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-06', '2013-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-07', '2013-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-08', '2013-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-09', '2013-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-10', '2013-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-11', '2013-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-12', '2014-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-01', '2014-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-02', '2014-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-03', '2014-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-04', '2014-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-05', '2014-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-06', '2014-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-07', '2014-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-08', '2014-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-09', '2014-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-10', '2014-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-11', '2014-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-12', '2015-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-01', '2015-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-02', '2015-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-03', '2015-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-04', '2015-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-05', '2015-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-06', '2015-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-07', '2015-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-08', '2015-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-09', '2015-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-10', '2015-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-11', '2015-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-12', '2016-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-01', '2016-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-02', '2016-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-03', '2016-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-04', '2016-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-05', '2016-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-06', '2016-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-07', '2016-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-08', '2016-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-09', '2016-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-10', '2016-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-11', '2016-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-12', '2017-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-01', '2017-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-02', '2017-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-03', '2017-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-04', '2017-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-05', '2017-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-06', '2017-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-07', '2017-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-08', '2017-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-09', '2017-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-10', '2017-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-11', '2017-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-12', '2018-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-01', '2018-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-02', '2018-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-03', '2018-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-04', '2018-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-05', '2018-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-06', '2018-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-07', '2018-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-08', '2018-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-09', '2018-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-10', '2018-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-11', '2018-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-12', '2019-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-01', '2019-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-02', '2019-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-03', '2019-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-04', '2019-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-05', '2019-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-06', '2019-07'], dtype='period[M]', name='Date')
# ...
# PeriodIndex(['2003-07', '2003-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-08', '2003-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-09', '2003-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-10', '2003-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-11', '2003-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2003-12', '2004-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-01', '2004-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-02', '2004-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-03', '2004-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-04', '2004-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-05', '2004-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-06', '2004-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-07', '2004-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-08', '2004-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-09', '2004-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-10', '2004-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-11', '2004-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2004-12', '2005-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-01', '2005-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-02', '2005-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-03', '2005-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-04', '2005-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-05', '2005-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-06', '2005-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-07', '2005-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-08', '2005-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-09', '2005-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-10', '2005-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-11', '2005-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2005-12', '2006-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-01', '2006-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-02', '2006-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-03', '2006-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-04', '2006-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-05', '2006-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-06', '2006-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-07', '2006-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-08', '2006-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-09', '2006-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-10', '2006-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-11', '2006-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2006-12', '2007-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-01', '2007-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-02', '2007-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-03', '2007-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-04', '2007-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-05', '2007-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-06', '2007-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-07', '2007-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-08', '2007-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-09', '2007-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-10', '2007-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-11', '2007-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2007-12', '2008-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-01', '2008-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-02', '2008-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-03', '2008-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-04', '2008-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-05', '2008-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-06', '2008-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-07', '2008-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-08', '2008-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-09', '2008-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-10', '2008-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-11', '2008-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2008-12', '2009-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-01', '2009-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-02', '2009-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-03', '2009-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-04', '2009-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-05', '2009-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-06', '2009-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-07', '2009-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-08', '2009-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-09', '2009-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-10', '2009-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-11', '2009-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2009-12', '2010-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-01', '2010-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-02', '2010-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-03', '2010-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-04', '2010-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-05', '2010-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-06', '2010-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-07', '2010-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-08', '2010-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-09', '2010-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-10', '2010-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-11', '2010-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2010-12', '2011-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-01', '2011-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-02', '2011-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-03', '2011-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-04', '2011-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-05', '2011-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-06', '2011-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-07', '2011-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-08', '2011-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-09', '2011-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-10', '2011-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-11', '2011-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2011-12', '2012-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-01', '2012-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-02', '2012-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-03', '2012-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-04', '2012-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-05', '2012-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-06', '2012-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-07', '2012-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-08', '2012-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-09', '2012-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-10', '2012-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-11', '2012-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2012-12', '2013-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-01', '2013-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-02', '2013-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-03', '2013-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-04', '2013-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-05', '2013-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-06', '2013-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-07', '2013-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-08', '2013-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-09', '2013-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-10', '2013-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-11', '2013-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2013-12', '2014-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-01', '2014-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-02', '2014-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-03', '2014-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-04', '2014-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-05', '2014-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-06', '2014-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-07', '2014-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-08', '2014-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-09', '2014-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-10', '2014-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-11', '2014-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2014-12', '2015-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-01', '2015-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-02', '2015-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-03', '2015-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-04', '2015-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-05', '2015-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-06', '2015-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-07', '2015-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-08', '2015-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-09', '2015-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-10', '2015-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-11', '2015-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2015-12', '2016-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-01', '2016-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-02', '2016-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-03', '2016-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-04', '2016-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-05', '2016-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-06', '2016-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-07', '2016-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-08', '2016-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-09', '2016-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-10', '2016-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-11', '2016-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2016-12', '2017-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-01', '2017-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-02', '2017-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-03', '2017-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-04', '2017-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-05', '2017-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-06', '2017-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-07', '2017-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-08', '2017-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-09', '2017-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-10', '2017-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-11', '2017-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2017-12', '2018-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-01', '2018-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-02', '2018-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-03', '2018-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-04', '2018-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-05', '2018-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-06', '2018-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-07', '2018-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-08', '2018-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-09', '2018-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-10', '2018-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-11', '2018-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2018-12', '2019-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-01', '2019-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-02', '2019-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-03', '2019-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-04', '2019-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-05', '2019-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-06', '2019-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-07', '2019-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-08', '2019-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-09', '2019-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-10', '2019-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-11', '2019-12'], dtype='period[M]', name='Date')
# PeriodIndex(['2019-12', '2020-01'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-01', '2020-02'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-02', '2020-03'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-03', '2020-04'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-04', '2020-05'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-05', '2020-06'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-06', '2020-07'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-07', '2020-08'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-08', '2020-09'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-09', '2020-10'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-10', '2020-11'], dtype='period[M]', name='Date')
# PeriodIndex(['2020-11', '2020-12'], dtype='period[M]', name='Date')
#          ptf_1_return  ptf_1_volume               ptf_1_stocks  ptf_2_return  \
# Date
# 2000-12           NaN     3294980.0    [WMT, F, CAT, UPS, MKC]           NaN
# 2001-01      0.037479     3779360.0    [NKE, F, CAT, UPS, MKC]      0.177179
# 2001-02     -0.039885     3477900.0    [WMT, F, CAT, UPS, MKC]     -0.148126
# 2001-03      0.032231     3597500.0    [WMT, F, CAT, MKC, UPS]     -0.031277
# 2001-04      0.032258     4405520.0    [NKE, F, CAT, MKC, UPS]      0.120112
# ...               ...           ...                        ...           ...
# 2020-08      0.098878     5241040.0  [WMT, UPS, CAT, NKE, MKC]      0.037041
# 2020-09      0.027482     6247880.0  [WMT, NKE, UPS, CAT, MKC]     -0.050831
# 2020-10     -0.025193     4996360.0  [WMT, NKE, UPS, CAT, MKC]     -0.010596
# 2020-11      0.090591     5886920.0  [NKE, WMT, UPS, CAT, MKC]      0.139027
# 2020-12      0.003007     3257600.0  [WMT, NKE, UPS, CAT, MKC]      0.034810
#
#          ptf_2_volume                 ptf_2_stocks
# Date
# 2000-12    36405000.0  [MSFT, INTC, JPM, XOM, NKE]
# 2001-01    38957900.0  [MSFT, INTC, XOM, JPM, WMT]
# 2001-02    35719760.0  [MSFT, INTC, NKE, XOM, JPM]
# 2001-03    32907900.0  [MSFT, INTC, NKE, XOM, JPM]
# 2001-04    29007320.0  [MSFT, INTC, XOM, JPM, WMT]
# ...               ...                          ...
# 2020-08    32891360.0    [F, INTC, MSFT, XOM, JPM]
# 2020-09    31221860.0    [F, INTC, MSFT, XOM, JPM]
# 2020-10    45232160.0    [F, INTC, MSFT, XOM, JPM]
# 2020-11    43478740.0    [F, XOM, INTC, MSFT, JPM]
# 2020-12    25464980.0    [F, INTC, XOM, MSFT, JPM]
#
# [2410 rows x 6 columns]

# %% [markdown]
# QUESTION 2 - portfolios sorted based on the average past size of company in previous n periods.
# p1 - 50% smallest (by volume) stocks in t-1,
# p2 - 50% biggest (by volume) stocks in t-1

# %%
# period = 1
# rebalance_period = 1
# small_p = .5
# big_p = .5

Q2 = constrcut_portfolios(df=df, decision_var="volume", reb=1, per=6, small_p=.5, big_p=.5)
Q2
# Out:
#          ptf_1_return  ptf_1_volume               ptf_1_stocks  ptf_2_return  \
# Date
# 2000-12           NaN     3294980.0    [WMT, F, CAT, UPS, MKC]           NaN
# 2001-01      0.037479     3779360.0    [NKE, F, CAT, UPS, MKC]      0.177179
# 2001-02     -0.039885     3477900.0    [WMT, F, CAT, UPS, MKC]     -0.148126
# 2001-03      0.032231     3597500.0    [WMT, F, CAT, UPS, MKC]     -0.031277
# 2001-04      0.029932     3848760.0    [WMT, F, CAT, UPS, MKC]      0.122438
# ...               ...           ...                        ...           ...
# 2020-08      0.098878     5241040.0  [WMT, NKE, UPS, CAT, MKC]      0.037041
# 2020-09      0.027482     6247880.0  [WMT, NKE, UPS, CAT, MKC]     -0.050831
# 2020-10     -0.025193     4996360.0  [WMT, NKE, UPS, CAT, MKC]     -0.010596
# 2020-11      0.090591     5886920.0  [WMT, NKE, UPS, CAT, MKC]      0.139027
# 2020-12      0.003007     3257600.0  [WMT, NKE, UPS, CAT, MKC]      0.034810
#
#          ptf_2_volume                 ptf_2_stocks
# Date
# 2000-12    36405000.0  [MSFT, INTC, JPM, XOM, NKE]
# 2001-01    38957900.0  [MSFT, INTC, XOM, JPM, WMT]
# 2001-02    35719760.0  [MSFT, INTC, NKE, XOM, JPM]
# 2001-03    32907900.0  [MSFT, INTC, XOM, NKE, JPM]
# 2001-04    29564080.0  [MSFT, INTC, XOM, NKE, JPM]
# ...               ...                          ...
# 2020-08    32891360.0    [F, MSFT, INTC, XOM, JPM]
# 2020-09    31221860.0    [F, MSFT, INTC, XOM, JPM]
# 2020-10    45232160.0    [F, INTC, MSFT, XOM, JPM]
# 2020-11    43478740.0    [F, INTC, MSFT, XOM, JPM]
# 2020-12    25464980.0    [F, INTC, MSFT, XOM, JPM]
#
# [2410 rows x 6 columns]

# %% [markdown]
# QUESTION 3 - portfolios sorted based on the average past size of company in previous n periods, portfolio components change every REB periods.
# p1 - 50% smallest (by volume) stocks in t-1,
# p2 - 50% biggest (by volume) stocks in t-1

# %%
Q3 = constrcut_portfolios(df=df, decision_var="volume", reb=12, per=6, small_p=.5, big_p=.5)
Q3
# Out:
#          ptf_1_return  ptf_1_volume               ptf_1_stocks  ptf_2_return  \
# Date
# 2000-12           NaN     3294980.0    [WMT, F, CAT, UPS, MKC]           NaN
# 2001-01      0.054190     4467380.0    [WMT, F, CAT, UPS, MKC]      0.160468
# 2001-02     -0.039885     3477900.0    [WMT, F, CAT, UPS, MKC]     -0.148126
# 2001-03      0.032231     3597500.0    [WMT, F, CAT, UPS, MKC]     -0.031277
# 2001-04      0.029932     3848760.0    [WMT, F, CAT, UPS, MKC]      0.122438
# ...               ...           ...                        ...           ...
# 2020-08      0.098878     5241040.0  [NKE, WMT, CAT, UPS, MKC]      0.037041
# 2020-09      0.027482     6247880.0  [NKE, WMT, CAT, UPS, MKC]     -0.050831
# 2020-10     -0.025193     4996360.0  [NKE, WMT, CAT, UPS, MKC]     -0.010596
# 2020-11      0.090591     5886920.0  [NKE, WMT, CAT, UPS, MKC]      0.139027
# 2020-12      0.003007     3257600.0  [NKE, WMT, CAT, UPS, MKC]      0.034810
#
#          ptf_2_volume                 ptf_2_stocks
# Date
# 2000-12    36405000.0  [MSFT, INTC, JPM, XOM, NKE]
# 2001-01    38269880.0  [MSFT, INTC, JPM, XOM, NKE]
# 2001-02    35719760.0  [MSFT, INTC, JPM, XOM, NKE]
# 2001-03    32907900.0  [MSFT, INTC, JPM, XOM, NKE]
# 2001-04    29564080.0  [MSFT, INTC, JPM, XOM, NKE]
# ...               ...                          ...
# 2020-08    32891360.0    [F, MSFT, INTC, XOM, JPM]
# 2020-09    31221860.0    [F, MSFT, INTC, XOM, JPM]
# 2020-10    45232160.0    [F, MSFT, INTC, XOM, JPM]
# 2020-11    43478740.0    [F, MSFT, INTC, XOM, JPM]
# 2020-12    25464980.0    [F, MSFT, INTC, XOM, JPM]
#
# [2410 rows x 6 columns]

# %% [markdown]
# QUESTION 4 - portfolios sorted based on the average past size of company in previous n periods, portfolio components change every REB periods.
# p1 - 30% smallest (by volume) stocks in t-1,
# p2 - 30% biggest (by volume) stocks in t-1

# %%
Q4 = constrcut_portfolios(df=df, decision_var="volume", reb=12, per=12, small_p=.3, big_p=.3)
Q4
# Out:
#          ptf_1_return  ptf_1_volume     ptf_1_stocks  ptf_2_return  \
# Date
# 2000-12           NaN  1.715267e+06  [CAT, UPS, MKC]           NaN
# 2001-01     -0.000334  2.311733e+06  [CAT, UPS, MKC]      0.282928
# 2001-02     -0.022604  1.612733e+06  [CAT, UPS, MKC]     -0.137767
# 2001-03      0.047273  1.957367e+06  [CAT, UPS, MKC]     -0.063196
# 2001-04      0.025581  2.350967e+06  [CAT, UPS, MKC]      0.160727
# ...               ...           ...              ...           ...
# 2020-08      0.091688  2.535533e+06  [CAT, UPS, MKC]      0.066442
# 2020-09      0.002593  3.643633e+06  [CAT, UPS, MKC]     -0.024856
# 2020-10     -0.024727  3.663200e+06  [CAT, UPS, MKC]     -0.007184
# 2020-11      0.076672  2.961200e+06  [CAT, UPS, MKC]      0.107951
# 2020-12      0.006770  2.328500e+06  [CAT, UPS, MKC]      0.006531
#
#          ptf_2_volume       ptf_2_stocks
# Date
# 2000-12  5.456273e+07  [MSFT, INTC, JPM]
# 2001-01  5.564127e+07  [MSFT, INTC, JPM]
# 2001-02  4.790680e+07  [MSFT, INTC, JPM]
# 2001-03  4.898723e+07  [MSFT, INTC, JPM]
# 2001-04  4.112407e+07  [MSFT, INTC, JPM]
# ...               ...                ...
# 2020-08  4.165927e+07    [F, MSFT, INTC]
# 2020-09  3.916167e+07    [F, MSFT, INTC]
# 2020-10  5.436020e+07    [F, MSFT, INTC]
# 2020-11  5.245587e+07    [F, MSFT, INTC]
# 2020-12  3.203987e+07    [F, MSFT, INTC]
#
# [2410 rows x 6 columns]
